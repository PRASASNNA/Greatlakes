# %% [markdown]
# # Exploratory Data Analysis on YouTube data

# %%
import pandas as pd
df = pd.read_csv('youtube_dislike_dataset.csv')
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# # 1.Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top5 and bottom 5 records.

# %%
TOP_5_RECORDS=df.head(5)
print("Top 5 records:")
TOP_5_RECORDS
# Out:
# Top 5 records:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %% [markdown]
# # 1(b)Bottom 5 records

# %%
BOTTOM_5_RECORDS=df.tail(5)
print("\nBottom 5 records")
BOTTOM_5_RECORDS
# Out:
# Bottom 5 records
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# ...

# %% [markdown]
# # 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
#check the info of the dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# # 2(b)shape

# %%
df.shape
# Out:
# (37422, 12)

# %% [markdown]
# Q.2
# #Inferences
# 1.Data types:The info() method will display the data types for each column.You can see if the data types are appropriate for the kind of the data stored in each column, such as int64 for integers, object for strings, and so on.
# 2.Shape of the Dataset: You can see the number of rows(entries) and columns in the dataset. The shape is represented as (number of rows, number of columns).

# %% [markdown]
# # 3. Check for the Percentage of the missing values and drop or impute them.

# %%
#step 1:Calculate the percentage of missing values in each column
missing_percentage=df.isnull().mean()* 100
missing_percentage
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
#step 2: Decide whether to drop or impute missing values
x=30 #threshold percentage
for column, Percentage in missing_percentage.items():
    if Percentage >x:
        print(f"Column '{column}' has {Percenatge:.2f}% missing values and wil be dropped.")
        df.drop(column, axis=1, inplace=True)
    else:
        if df[column].dtype !='object':
            df[column].fillna(df[column].mean(), inplace=True)
print('Percentage of the missing values:',Percentage)
# Out:
# Percentage of the missing values: 0.4222115333226444

# %% [markdown]
# # 4.Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
#NUMERICAL COLUMS
NUMERICAL=df.describe()
NUMERICAL
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
# CATEGORICAL COLUMNS
CATEGORICAL=df.describe(include=['object'])
CATEGORICAL
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description  \
# count                 37422  37422       37422
# unique                36772  28799       35630
# top     2020-10-16 04:00:10
# freq                      6   3817         589
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %% [markdown]
# Q.4
# #INFERENCES
# 1.The dataset contains a large number of unique video IDs, titles, channel IDs, and channel titles. This indicates that the dataset is representative of a wide variety of youtube videos.
# 2.The mean view count, like count, and comment count are all relatively high. This indicates that the videos in the dataset are generally popular and engaging.

# %% [markdown]
# # 5.Convert datatype of column published_at from object to pandas datetime.

# %%
#CONVERT THE "published_at" COLUMN TO PANDAS DATATIME
df['pubished_at']=pd.to_datetime(df['published_at'])
print(df['published_at'])
# Out:
# 0        2021-07-01 10:00:00
# 1        2021-06-10 16:00:00
# 2        2021-09-20 01:03:32
# 3        2021-03-03 10:00:17
# 4        2021-12-07 13:00:00
#                 ...
# 37417    2021-02-12 05:03:49
# 37418    2021-01-16 05:39:05
# 37419    2021-06-02 09:00:10
# 37420    2020-10-20 20:59:30
# 37421    2021-05-23 21:00:31
# Name: published_at, Length: 37422, dtype: object

# %% [markdown]
# # 6.Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df['published_at']=pd.to_datetime(df['published_at'])
#'published_month' USING THE COLUMN published_at (DISPLAY THE MONNTHS ONLY)
df['published_month']=df['published_at'].dt.month
df['published_month']
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37422, dtype: int32

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# # 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on....

# %%
month_mapping={
    1:'Jan',
    2:'Feb',
    3:'Mar',
    4:'Apr',
    5:'May',
    6:'Jun',
    7:'Jul',
    8:'Aug',
    9:'Sep',
    10:'Oct',
    11:'Nov',
    12:'Dec'
}
#REPLACE THE NUMBERS WITH MONTH NAMES IN THE 'published_month' COLUMN
df['published_month']=df['published_month'].map(month_mapping)
df['published_month']
# Out:
# 0        Jul
# 1        Jun
# 2        Sep
# 3        Mar
# 4        Dec
#         ...
# 37417    Feb
# 37418    Jan
# 37419    Jun
# 37420    Oct
# 37421    May
# Name: published_month, Length: 37422, dtype: object

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# # 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count

# %%
#CONVERT THE published_at COLUMN TO PANDAS DATETIME
df['published_at']=pd.to_datetime(df['published_at'])

#CREATE A NEW COLUMN AS published_month
df['published_month']=df['published_at'].dt.month
df['published_month']=df['published_month'].map(month_mapping)

#COUNT THE NUMBER OF VIDEOS PUBLISHED EACH MONTH
MONTH_COUNTS=df['published_month'].value_counts()

#SORT THE MONTH COUNTS IN DECREASING ORDER
SORTED_MONTH_COUNTS=MONTH_COUNTS.sort_values(ascending=False)

#PRINT THE SORTED MONTH COUNTS
SORTED_MONTH_COUNTS
# Out:
# published_month
# Oct    4991
# Sep    4880
# Nov    4851
# Aug    4262
# Dec    3072
# Jul    2340
# Jun    2316
# Mar    2258
# Feb    2137
# Apr    2126
# Jan    2108
# May    2081
# Name: count, dtype: int64

# %% [markdown]
# # 9. Find the count of unique video_id, channel_id and channel_title.

# %%
#COUNT  OF UNIQUE VIDEO IDs:
UNIQUE_VIDEO_ID_COUNT=df['video_id'].nunique()
print("count of unique video IDs:",UNIQUE_VIDEO_ID_COUNT)
#COUNT OF UNIQUE CHANNEL IDs:
UNIQUE_CHANNEL_ID_COUNT=df['channel_id'].nunique()
print("count of unique channel IDs:",UNIQUE_CHANNEL_ID_COUNT)
#COUNT OF UNIQUE CHANNEL TITLES:
UNIQUE_CHANNEL_TITLE_COUNT=df['channel_title'].nunique()
print("Count of unique channel titles:",UNIQUE_CHANNEL_TITLE_COUNT)
# Out:
# count of unique video IDs: 37422
# count of unique channel IDs: 10961
# Count of unique channel titles: 10883

# %% [markdown]
# # 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
#COUNT THE NUMBER OF VIDEOS PER CHANNEL AND SORT IN DESCENDING ORDER
CHANNEL_VIDEO_COUNTS=df['channel_title'].value_counts()

#FIND THE TOP 10 CHANNELS WITH THE HIGHEST NUMBER OF VIDEOS
TOP_10_CHANNELS=CHANNEL_VIDEO_COUNTS.head(10)

#FIND THE BOTTOM 10 CHANNELS WITH THE LOWEST NUMBER OF VIDEOS
BOTTOM_10_CHANNELS=CHANNEL_VIDEO_COUNTS.tail(10)

#TOP 10 CHANNEL 
print("Top 10 channels with the highest nummber  of videos:")
print(TOP_10_CHANNELS)

#BOTTOM 10 CHANNELS
print("\nBottom 10 channels with the lowest number of videos:")
print(BOTTOM_10_CHANNELS)
# Out:
# Top 10 channels with the highest nummber  of videos:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: count, dtype: int64
#
# Bottom 10 channels with the lowest number of videos:
# channel_title
# Eiaz                     1
# adidas                   1
# Universitetet i Agder    1
# Team Tapia               1
# TheVincentMottola        1
# Blocktrainer             1
# Movie Addicts            1
# 1 1 minute mom           1
# FLORIN CERCEL            1
# Master Podcast           1
# Name: count, dtype: int64

# %% [markdown]
# # 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
#THE TITLE OF THE VIDEO WITH THE MAXIMUM NUMBER  OF LIKES
MAX_LIKES_TITLE=df[df['likes'] == df['likes'].max()]['title'].values[0]

#THE TITLE OF THE VIDEO WITH THE MINIMUM NUMBER OF LIKES
MIN_LIKES_TITLE=df[df['likes'] == df['likes'].min()]['title'].values[0]

#DISPLAY THE RESULTS
print("Title of the video with the maximum likes:", MAX_LIKES_TITLE)
print("Title of the video with the minimum likes:", MIN_LIKES_TITLE)
# Out:
# Title of the video with the maximum likes: BTS () 'Dynamite' Official MV
# Title of the video with the minimum likes: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# Q.11
# #INFERENCES
# 1.THE VIDEO WITH THE MAXIMUM NUMBER OF LIKES IS "BTS () 'DYNAMITE' OFFICIAL MV", THIS VIDEO IS A MUSIC VIDEO BY THE POPULAR KOREAN BOY BAND BTS, WHICH FEATURES THEM SINGING AND DANCEING TO A CATCHY DISCO-POP SONG.
# 2.THE VIDEO WITH THE MINIMUM NUMBER OF LIKES IS ' Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News' WHICH HAS 0 LIKES.

# %% [markdown]
# # 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your

# %%
#FIND THE TITLE OF THE VIDEO WITH THE MAXIMUM NUMBER OF DISLIKES
MAX_DISLIKES_TITLE=df[df['dislikes'] == df['dislikes'].max()]['title'].values[0]

#FIND THE TITLE OF THE VIDEO WITH THE MINIMUM NUMBER OF DISLIKES
MIN_DISLIKES_TITLE=df[df['dislikes'] == df['dislikes'].min()]['title'].values[0]

#DISPLAY THE RESULTS
print("Title of the video with the maximum dislikes:", MAX_DISLIKES_TITLE)
print("Title of the video with the minimum dislikes:", MIN_DISLIKES_TITLE)
# Out:
# Title of the video with the maximum dislikes: Cuties | Official Trailer | Netflix
# Title of the video with the minimum dislikes: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# Q.12
# #INFERENCES:
# !My Inferences may include understanding the videos content and viewer engagement,as well as potential factors that contributed to the high or low dislike counts.
# It can also provide insights into the audience preferences and sentiments regarding these videos.

# %% [markdown]
# # 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
CORRELATION_MATRIX=df['view_count'].corr(df['dislikes'])
CORRELATION_MATRIX
# Out:
# 0.6844687753905536

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,3))
sns.scatterplot(x='view_count',
                y='dislikes',
                data=df)
plt.xlabel('Views')
plt.ylabel('Dislikes')
plt.title('Scatter plot')
plt.show()

# %% [markdown]
# # 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
df['published_at'] = pd.to_datetime(df['published_at'])

#CREATE A NEW COLUMN AS published_month
df['published_month']=df['published_at'].dt.month
df['published_month']=df['published_month'].map(month_mapping)

#FILTER THE DATASET TO INCLUDE ONLY VIDEOS PUBLISHED IN JANUARY
JANYUARY_VIDEOS=df[df['published_month'] == 'Jan']

#DISPLAY ALL THE INFORMATION ABOUT THESE VIDEOS
print("Videos published in January")
JANYUARY_VIDEOS
# Out:
# Videos published in January
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
#MENTIO THE COUNT OF VIDEOS PUBLISHED IN JANUARY
COUNT_JANUARY_VIDEOS=len(JANYUARY_VIDEOS)
print("Count of videos published in January:",COUNT_JANUARY_VIDEOS )
# Out:
# Count of videos published in January: 2108

# %% [markdown]
# # Thank You!
