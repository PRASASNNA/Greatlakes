# %% [markdown]
# # 1. Import required libraries and read the dataset.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import seaborn as sns

# to suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
x= pd.read_csv('honeyproduction.csv')
x
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
x.shape
# Out:
# (626, 8)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
x.size
# Out:
# 5008

# %%
x.ndim
# Out:
# 2

# %%
x.isnull().sum()
# Out:
# state          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %%
x.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %% [markdown]
# # 3.  Display the percentage distribution of the data in each year using the pie chart.

# %%
year_counts = x['year'].value_counts()

# Get the labels and counts for the pie chart
labels = year_counts.index
counts = year_counts.values

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=80)

# Set a title
plt.title('Percentage Distribution of Data by Year')

# Display the pie chart
plt.show()

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
plt.figure(figsize=(4,4))

sns.displot(data=x['priceperlb'], kde=True,bins=6,color='green',common_norm = True)

plt.title("Distribution Plot for price per lb ")
plt.show()

# %% [raw]
# Findings
#
# 1.The distribution plot shows that the price per pound of honey is not normally distributed. The distribution is right-skewed, with a long tail to the right. This means that there are a few hives with very high prices per pound of honey.
#
# 2.The median price per pound of honey is $3.50. This means that half of the hives have a price per pound of honey that is higher than $3.50 and the other half have a price per pound of honey that is lower than $3.50.
#
# 3.The interquartile range (IQR), which is the difference between the third and first quartiles, is $1.25. This means that the middle 50% of hives have a price per pound of honey that is between $2.25 and $4.50.

# %% [markdown]
# # 5.Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and wite your findings

# %%
# Create the scatterplot
plt.scatter(x['numcol'], x['prodvalue'])

# Add labels and title
plt.xlabel('numcol')
plt.ylabel('prodval')
plt.title('Scatterplot of numcol vs. prodvale')
plt.grid(True)

# Show the plot
plt.show()

# %% [raw]
# Findings
#
# 1.The scatterplot shows a positive correlation between numcol and prodval. This means that as the number of colonies in a hive increases, the production of honey also tends to increase. However, the correlation is not perfect, which means that there are other factors that also influence the production of honey.
#
# 2.This finding is consistent with the intuition that hives with more colonies are able to produce more honey. This is because more colonies means more bees, which can forage for more nectar and pollinate more flowers.

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
# Create a box plot of prodval by year
sns.boxplot(
    x = 'year',
    y = 'prodvalue',
    showmeans=True,
    data=x
)

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Production value (USD)')
plt.title('Box plot of production value by year')
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %% [raw]
# Findings
#
# 1.The boxplot shows that the production value of honey has increased over time. The median production value has increased from around $200,000 in 2010 to over $400,000 in 2020.
#
# 2.The boxplot also shows that there is a lot of variation in the production value of honey, even within the same year. The interquartile range (IQR), which is the difference between the third and first quartiles, is quite large for each year. This suggests that there are a number of factors that are influencing the production value of honey, such as the number of colonies, the yield per colony, the price of honey per pound, and the weather.

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
# Assuming you have a DataFrame 'df' with the specified columns
selected_columns = ['numcol', 'yieldpercol', 'totalprod', 'prodvalue','year']

# Filter the DataFrame to include only the selected columns
df_selected = x[selected_columns]

# Create a pairplot
sns.set(style="ticks")
sns.pairplot(df_selected, hue="year")
plt.show()

# %% [raw]
# Inferences
#
# 1.The pairplot shows that the relationship between the variables is generally consistent across different years. For example, there is a strong positive correlation between numcol and prodval, regardless of the year.
#
# 2.However, there are some differences in the relationships between the variables across different years. For example, the correlation between yield percol and total prod appears to be stronger in recent years.
#
# 3.The pairplot suggests that the number of colonies and the yield per colony are the most important factors that influence the production and value of honey.
#
# 4.However, the relationship between these variables and other factors, such as the weather and the availability of food sources, may vary from year to year.

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yieldpercol','totalprod', 'stocks', 'priceperlb', 'prodvalue')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Calculate the correlation matrix
corr_matrix = x[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']].corr()

# Display the correlation matrix as a heatmap
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation matrix of honey production data')
plt.show()

# %% [markdown]
# Inferences
# The heatmap shows that there is a strong positive correlation between the following variables:
# 1.numcol and prodval
# 2.numcol and totalprod
# 3.totalprod and prodval
# This means that hives with more colonies tend to produce more honey and have a higher value.
#
# There is also a moderate positive correlation between the following variables:
#
# 1.yieldpercol and prodval
# 2.yieldpercol and totalprod
# 3.This means that hives with a higher yield per colony tend to produce more honey and have a higher value.
#
# However, there is a weak positive correlation between the following variables:
#
# 1.priceperlb and prodval
# 2.priceperlb and totalprod
# This means that the price of honey per pound does not have a strong relationship with the production of honey.
